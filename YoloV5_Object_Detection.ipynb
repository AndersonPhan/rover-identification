# %%
# Install Dependencies

# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5

# %%
# !pip install -qr requirements.txt  # install dependencies

import torch
import sys
sys.path.append('./') # Add current directory to Python path for local imports

from IPython.display import Image, clear_output  # to display images
from utils.downloads import attempt_download  # Reverted to original import

# Robustly determine device status
device_status = 'CPU'
if torch.cuda.is_available():
    try:
        gpu_properties = torch.cuda.get_device_properties(0)
        device_status = f"{gpu_properties.name} (Arch: {gpu_properties.major}.{gpu_properties.minor})"
    except RuntimeError:
        device_status = 'CPU (CUDA available but properties error)'

print(f"Setup complete. Using torch {torch.__version__} {device_status}")

# %%
# !pip install roboflow

# Skip this step if dataset was downloaded directly, if not cloen from Roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="API Key")
project = rf.workspace("auto-nav-rover").project("rover-identifcation-v3")
dataset = project.version(1).download("yolov5")

# %%
# %%time
# !python /content/yolov5/yolov5/train.py \
  --img 640 \
  --batch 16 \
  --epochs 150 \
  --data Rover-Identifcation-V3-1/data.yaml \
  --weights yolov5s.pt \
  --name box_yolov5s \
  --cache

# %%
from google.colab import files
files.download('/content/yolov5/runs/train/box_yolov5s/weights/best.pt')
